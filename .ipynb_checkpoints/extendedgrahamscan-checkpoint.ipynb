# %% [markdown]
# # Extended Graham scan algorithm

# %% [markdown]
# Use the cell below for all python code needed to realise the extended Graham scan algorithm (including any auxiliary data structures and functions you might need). The `extendedgrahamscan()` function itself should take as input parameter a list of 2D points (`inputSet`), and return the subset of such points that lie on the convex hull (`outputSet`).

# %%
#def extendedgrahamscan(inputSet):
import math
import random
import matplotlib.pyplot as plt
from collections import deque

def findMost(inputSet):
    b,t,l,r = inputSet[0],inputSet[0],inputSet[0],inputSet[0]
    for i in range(1,len(inputSet)):
        if inputSet[i][1] < b[1]:
            b = inputSet[i]
        elif inputSet[i][1] == b[1] and inputSet[i][0] < b[0]:
            b = inputSet[i]
        if inputSet[i][1] > t[1]:
            t = inputSet[i]
        elif inputSet[i][1] == t[1] and inputSet[i][0] > t[0]:
            t = inputSet[i]
        if inputSet[i][0] < l[0]:
            l = inputSet[i]
        elif inputSet[i][0] == l[0] and inputSet[i][1] > l[1]:
            l = inputSet[i]
        if inputSet[i][0] > r[0]:
            r = inputSet[i]
        elif inputSet[i][0] == r[0] and inputSet[i][1] < r[1]:
            r = inputSet[i]
    return b,t,l,r

def findBottomMost(inputSet):
    bottomMost = inputSet[0]
    for i in range(1,len(inputSet)):
        if inputSet[i][1] < bottomMost[1]:
            bottomMost = inputSet[i]
        elif inputSet[i][1] == bottomMost[1] and inputSet[i][0] < bottomMost[0]:
            bottomMost = inputSet[i]
    return bottomMost

def findTopMost(inputSet):
    topMost = inputSet[0]
    for i in range(1,len(inputSet)):
        if inputSet[i][1] > topMost[1]:
            topMost = inputSet[i]
        elif inputSet[i][1] == topMost[1] and inputSet[i][0] > topMost[0]:
            topMost = inputSet[i]
    return topMost

def findLeftMost(inputSet):
    leftMost = inputSet[0]
    for i in range(1,len(inputSet)):
        if inputSet[i][0] < leftMost[0]:
            leftMost = inputSet[i]
        elif inputSet[i][0] == leftMost[0] and inputSet[i][1] > leftMost[1]:
            leftMost = inputSet[i]
    return leftMost

def findRightMost(inputSet):
    rightMost = inputSet[0]
    for i in range(1,len(inputSet)):
        if inputSet[i][0] > rightMost[0]:
            rightMost = inputSet[i]
        elif inputSet[i][0] == rightMost[0] and inputSet[i][1] < rightMost[1]:
            rightMost = inputSet[i]
    return rightMost

def findPerpendicular(p1,p2,inputSet):
    if len(inputSet) == 0: return
    target = inputSet[0]
    for p in inputSet:
        if abs(crossProduct(p1,p2,p)) > abs(crossProduct(p1,p2,target)):
            target = p
    return target

def polarAngle(p1,p2):
    return (p2[0]-p1[0])/math.sqrt(distance(p1,p2))

def distance(p2,p1):
    return (p2[0]-p1[0])**2 + (p2[1]-p1[1])**2

def crossProduct(p1,p2,p3):
    y1 = p2[1] - p1[1]
    y2 = p3[1] - p1[1]
    x1 = p2[0] - p1[0]
    x2 = p3[0] - p1[0]
    return y2 * x1 - y1 * x2

def partitionrand(arr,lo,hi,start):
 
    randpivot = random.randrange(lo, hi)

    arr[lo], arr[randpivot] = arr[randpivot], arr[lo]
    return partition(arr,lo,hi,start)


def partition(arr,lo,hi,start):
    i = lo+1
    j = hi
    p = arr[lo]

    while True:
        while polarAngle(start,arr[i]) > polarAngle(start,p) or (polarAngle(start,arr[i])==polarAngle(start,p) and ((polarAngle(start,arr[i]) >= 0 and distance(start,arr[i]) < distance(start,p)) or (polarAngle(start,arr[i]) < 0 and distance(start,arr[i]) > distance(start,p)))):
            if i==hi: break
            i+=1
        while polarAngle(start,p) > polarAngle(start,arr[j]) or (polarAngle(start,arr[j])==polarAngle(start,p) and ((polarAngle(start,arr[j]) >= 0 and distance(start,arr[j]) > distance(start,p)) or (polarAngle(start,arr[j]) < 0 and distance(start,arr[j]) < distance(start,p)))):
            if j==lo: break
            j-=1
        if i >= j: break
        arr[i],arr[j] = arr[j],arr[i]
    arr[lo],arr[j] = arr[j],arr[lo]
    return j

def quickSortHelper(a,lo,hi,start):
    if hi <= lo: return
    j = partition(a,lo,hi,start)
    quickSortHelper(a,lo,j-1,start)
    quickSortHelper(a,j+1,hi,start)

def quickSort(inputSet,start):
    quickSortHelper(inputSet,0,len(inputSet)-1,start)
    return inputSet

def quickSort_NonRecur(a,start):
    stack = deque()
    lo = 0
    hi = len(a)-1
    stack.append((lo,hi))
    

    while stack:
        lo,hi = stack.pop()
        pivotIndex = partition(a,lo,hi,start)

        if pivotIndex-1>lo:
            stack.append((lo,pivotIndex-1))
        if pivotIndex+1<hi:
            stack.append((pivotIndex+1,hi))
            
    return a

def eliminateDots(inputSet):
    res = inputSet.copy()
    res2 = inputSet.copy()
    b,t,l,r = findMost(res)
    edgeDots = [b,r,t,l,b]
    plt.figure()
    input_xs, input_ys = zip(*res)
    plt.scatter(input_xs, input_ys)
    input_xs, input_ys = zip(*edgeDots)
    plt.plot(input_xs, input_ys)
    
#     #plot first heuristic shape
#     edgeDots = [b,r,t,l,b]
#     plt.figure()
#     input_xs, input_ys = zip(*edgeDots)
#     plt.plot(input_xs, input_ys)
    
#     topLeft = []
#     bottomRight = []
#     topRight = []
#     bottomLeft = []
    
#     center = []
#     #plot initial input dots
#     input_xs, input_ys = zip(*res)
#     plt.scatter(input_xs, input_ys)
#     print(len(res))

    targets = [0,0,0,0]
    res3 = []
    for p in res2: #need to be res2 instead of res, because res will be changed in the loop
        v = dotInArea(b,t,l,r,p)
        if v[0] != 0:
#             center.append(p)
            res3.append(p)
    
#         elif v[0] == 1:
#             topLeft.append(p)
#         elif v[0] == 2:
#             bottomRight.append(p)
#         elif v[0] == 3:
#             topRight.append(p)
#         elif v[0] == 4:
#             bottomLeft.append(p)
            
#     print("center: ",len(center))
#     print("topLeft: ",len(topLeft))
#     print("bottomRight: ",len(bottomRight))
#     print("topRight: ",len(topRight))
#     print("bottomLeft: ",len(bottomLeft))
#     print("totle: ",len(center)+len(topLeft)+len(bottomRight)+len(topRight)+len(bottomLeft))

#     #plot after removing all dots in the central area
#     input_xs, input_ys = zip(*res)
#     plt.scatter(input_xs, input_ys)


#     if len(topLeft)!=0:
#         l1 = [l,t,findPerpendicular(l,t,topLeft),l]
#         input_xs, input_ys = zip(*l1)
#         plt.plot(input_xs, input_ys)
#     if len(bottomRight)!=0:
#         l2 = [r,b,findPerpendicular(r,b,bottomRight),r]
#         input_xs, input_ys = zip(*l2)
#         plt.plot(input_xs, input_ys)
#     if len(topRight)!=0:
#         l3 = [t,r,findPerpendicular(t,r,topRight),t]
#         input_xs, input_ys = zip(*l3)
#         plt.plot(input_xs, input_ys)
#     if len(bottomLeft)!=0:
#         l4 = [b,l,findPerpendicular(b,l,bottomLeft),b]
#         input_xs, input_ys = zip(*l4)
#         plt.plot(input_xs, input_ys)

#     for p in topLeft:
#         if dotInTriangle(l,t,findPerpendicular(l,t,topLeft),p):
#             res.remove(p)
#     for p in bottomRight:
#         if dotInTriangle(r,b,findPerpendicular(r,b,bottomRight),p):
#             res.remove(p)
#     for p in topRight:
#         if dotInTriangle(t,r,findPerpendicular(t,r,topRight),p):
#             res.remove(p)
#     for p in bottomLeft:
#         if dotInTriangle(b,l,findPerpendicular(b,l,bottomLeft),p):
#             res.remove(p)
#     plt.figure()
#     input_xs, input_ys = zip(*res)
#     plt.scatter(input_xs, input_ys)
    return res3

def dotInTriangle(p1,p2,p3,point): #p1,p2,p3 should be in anti-clockwise position
    if p1==p3 or p2==p3 or p1==p2: return
    v1 = crossProduct(p1,p2,point)
    v2 = crossProduct(p2,p3,point)
    v3 = crossProduct(p3,p1,point)
    if v1 > 0 and v2 > 0 and v3 > 0:
        return True
    return False


def dotInArea(b,t,l,r,point):
    v1 = crossProduct(b,r,point)
    v2 = crossProduct(r,t,point)
    v3 = crossProduct(t,l,point)
    v4 = crossProduct(l,b,point)
    if v1 > 0 and v2 > 0 and v3 > 0 and v4 > 0:  #in middle
        return (0,0)
    elif v3 < 0:  #top left
        return (1,v3)
    elif v1 < 0:  #bottom right
        return (2,v1)
    elif v2 < 0:  #top right
        return (3,v2)
    elif v4 < 0:
        return (4,v4) #bottom left
    return (-1,-1)
       
@profile
def grahamscan(inputSet):
    if len(inputSet) <= 2: return
    inputSet = eliminateDots(inputSet)
#     plt.figure()
#     input_xs, input_ys = zip(*inputSet)
#     plt.scatter(input_xs, input_ys)
    start = findBottomMost(inputSet)
    inputSet.remove(start)
    sortedSet = quickSort_NonRecur(inputSet,start)
    sortedSet.append(start)
    outputSet = [start,sortedSet[0]]
    for point in sortedSet:
        while len(outputSet) >= 2 and crossProduct(outputSet[-2],outputSet[-1],point) <= 0:
            del outputSet[-1]
        outputSet.append(point)
    return outputSet


#    return outputSet

# %% [markdown]
# A profilling decorator @profile

# %%
import cProfile, pstats, io

def profile(fuc):
    def inner(*args, **kwargs):
        pr = cProfile.Profile()
        pr.enable()
        retval = fuc(*args, **kwargs)
        pr.disable()
        s = io.StringIO()
        sortby = 'cumulative'
        ps = pstats.Stats(pr, stream=s).sort_stats(sortby)
        ps.print_stats()
        print(s.getvalue())
        return retval
    return inner

# %% [markdown]
# Use the cell below for all python code needed to generate test data points (both random and those representing worst-case scenario).

# %%
from random import *

from math import *

import matplotlib.pyplot as plt



# #Point objects have x and y coordinates

# class Point(object):
#     def __init__(self, x, y):
#         self.x = x
#         self.y = y

MAXX = 32767
MAXY = 32767
MINX = 0
MINY = 0
MIDDLE = [(MAXX-MINX)/2, (MAXY-MINY)/2]
NS = [100, 500, 1000, 5000, 10000, 15000, 20000]

def generate_random(N):
    points = []
    for p in range(N):
        while True:
            x = randint(MINX, MAXX)
            y = randint(MINY, MAXY)
            point = [x,y]
            if point not in points:
                break
        points.append(point)
        
    return points

def generate_hull(N):
    angle = 0
    radius = 16383.5
    for p in range(N + 100):
        x = ceil(MIDDLEp[0] + (radius * cos(angle)))
        y = ceil(MIDDLE[1] + (radius * sin(angle)))
        point = [x,y]
        points.append(point)
        angle += (2*pi)/N
    return points 

inputSets = [generate_random(NS[n]) for n in range(7)]

# %%
def runningTime(func,*args):

    haveArgs=True

    if len(args) ==0:

        haveArgs=False

    if haveArgs:

        startTime=time.time()

        func(args[0])

        return time.time() - startTime

    else:

        startTime=time.time()

        func()

        return time.time() - startTime

# %% [markdown]
# Use the cell below for all python code needed to test the `extendedgrahamscan()` function on the data generated above.

# %%
import timeit

def timer():
    l = [(timeit.timeit(lambda: grahamscan(inputSets[n]), number = n)) for n in range(7)]
    print(l)

#timer()
#inputSet = generate_random(100000)
inputSet = inputSets[0]
outputSet = grahamscan(inputSet)
# Out:
#          46733 function calls (46237 primitive calls) in 0.036 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.036    0.036 <ipython-input-341-dba1344884fb>:255(grahamscan)
#         1    0.000    0.000    0.034    0.034 <ipython-input-341-dba1344884fb>:138(eliminateDots)
#         1    0.000    0.000    0.033    0.033 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/pyplot.py:2884(scatter)
#         3    0.000    0.000    0.029    0.010 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/pyplot.py:2366(gca)
#         3    0.000    0.000    0.029    0.010 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/figure.py:2021(gca)
#         1    0.000    0.000    0.029    0.029 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/figure.py:1254(add_subplot)
#         1    0.000    0.000    0.029    0.029 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/axes/_subplots.py:18(__init__)
#         1    0.000    0.000    0.029    0.029 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/axes/_base.py:434(__init__)
#         1    0.000    0.000    0.021    0.021 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/axes/_base.py:1038(cla)
#   323/112    0.001    0.000    0.018    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/cbook/deprecation.py:384(wrapper)
#         8    0.000    0.000    0.015    0.002 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/axis.py:815(set_tick_params)
#         2    0.000    0.000    0.013    0.006 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/axes/_base.py:2851(grid)
#         4    0.000    0.000    0.013    0.003 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/axis.py:1401(grid)
#       6/4    0.000    0.000    0.012    0.003 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/axis.py:607(__get__)
#       104    0.000    0.000    0.011    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/artist.py:1086(set)
#        14    0.000    0.000    0.006    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/axis.py:341(_apply_params)
#         6    0.000    0.000    0.006    0.001 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/axis.py:56(__init__)
#       323    0.000    0.000    0.006    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/inspect.py:3020(bind)
#       323    0.004    0.000    0.006    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/inspect.py:2889(_bind)
#         3    0.000    0.000    0.006    0.002 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/axis.py:2301(_get_tick)
#         3    0.000    0.000    0.006    0.002 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/axis.py:489(__init__)
#         3    0.000    0.000    0.006    0.002 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/axis.py:2011(_get_tick)
#         3    0.000    0.000    0.006    0.002 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/axis.py:416(__init__)
#         2    0.000    0.000    0.005    0.003 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/axis.py:899(set_clip_path)
#         1    0.000    0.000    0.005    0.005 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/axes/_base.py:611(_init_axis)
#        16    0.000    0.000    0.004    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/axis.py:754(_set_scale)
#        16    0.000    0.000    0.004    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/scale.py:106(set_default_locators_and_formatters)
#   405/360    0.001    0.000    0.004    0.000 {built-in method numpy.core._multiarray_umath.implement_array_function}
#       146    0.001    0.000    0.004    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/artist.py:972(update)
#        12    0.000    0.000    0.004    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/axis.py:770(cla)
#        19    0.000    0.000    0.003    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/lines.py:269(__init__)
#         1    0.000    0.000    0.003    0.003 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/__init__.py:1444(inner)
#         1    0.000    0.000    0.003    0.003 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/axes/_axes.py:4312(scatter)
#        16    0.000    0.000    0.003    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/ticker.py:2896(__init__)
#        16    0.000    0.000    0.003    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/ticker.py:2096(__init__)
#         2    0.000    0.000    0.002    0.001 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/axes/_base.py:3013(tick_params)
#        16    0.000    0.000    0.002    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/ticker.py:2169(set_params)
#        19    0.000    0.000    0.002    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/text.py:127(__init__)
#        16    0.000    0.000    0.002    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/artist.py:723(set_clip_path)
#         2    0.000    0.000    0.002    0.001 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/axis.py:664(__init__)
#        63    0.000    0.000    0.002    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/text.py:168(update)
#         1    0.000    0.000    0.002    0.002 <ipython-input-341-dba1344884fb>:120(quickSort_NonRecur)
#        29    0.000    0.000    0.002    0.000 <ipython-input-341-dba1344884fb>:93(partition)
#         1    0.000    0.000    0.002    0.002 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/axis.py:2260(__init__)
#         1    0.000    0.000    0.002    0.002 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/axis.py:1972(__init__)
#        16    0.000    0.000    0.002    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/patches.py:258(get_transform)
#         4    0.000    0.000    0.001    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/spines.py:221(register_axis)
#       908    0.000    0.000    0.001    0.000 <ipython-input-341-dba1344884fb>:72(polarAngle)
#        16    0.000    0.000    0.001    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/patches.py:791(get_patch_transform)
#         3    0.000    0.000    0.001    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/numpy/ma/core.py:6675(__call__)
#        16    0.000    0.000    0.001    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/patches.py:761(_update_patch_transform)
#         6    0.000    0.000    0.001    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/axis.py:228(set_clip_path)
#         4    0.000    0.000    0.001    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/numpy/ma/core.py:2782(__new__)
#         3    0.000    0.000    0.001    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/numpy/ma/core.py:7852(asanyarray)
#        16    0.000    0.000    0.001    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/ticker.py:2161(_staircase)
# 1267/1095    0.001    0.000    0.001    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/artist.py:213(stale)
#        19    0.000    0.000    0.001    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/text.py:1190(set_fontproperties)
#        16    0.000    0.000    0.001    0.000 <__array_function__ internals>:2(hstack)
#         2    0.000    0.000    0.001    0.001 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/numpy/ma/core.py:2831(<listcomp>)
#       105    0.001    0.000    0.001    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/cbook/__init__.py:1682(normalize_kwargs)
#       202    0.000    0.000    0.001    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/numpy/ma/core.py:1430(getmaskarray)
#        38    0.000    0.000    0.001    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/font_manager.py:680(__init__)
#        16    0.000    0.000    0.001    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/ticker.py:2146(_validate_steps)
#        57    0.000    0.000    0.001    0.000 <__array_function__ internals>:2(any)
#      2266    0.000    0.000    0.001    0.000 {built-in method builtins.next}
#        16    0.000    0.000    0.001    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/numpy/core/shape_base.py:286(hstack)
#       565    0.001    0.000    0.001    0.000 {built-in method numpy.array}
#         7    0.000    0.000    0.001    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/lines.py:1005(get_path)
#         1    0.000    0.000    0.001    0.001 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/axes/_base.py:1917(add_collection)
#         7    0.000    0.000    0.001    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/lines.py:650(recache)
#         4    0.000    0.000    0.001    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/spines.py:234(cla)
#        32    0.000    0.000    0.001    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/markers.py:277(set_marker)
#        57    0.000    0.000    0.001    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/numpy/core/fromnumeric.py:2236(any)
#      1244    0.001    0.000    0.001    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/__init__.py:686(__getitem__)
#       920    0.001    0.000    0.001    0.000 <ipython-input-341-dba1344884fb>:75(distance)
#        28    0.000    0.000    0.001    0.000 <__array_function__ internals>:2(concatenate)
#        64    0.000    0.000    0.001    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/numpy/core/fromnumeric.py:73(_wrapreduction)
#       353    0.000    0.000    0.001    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/numpy/core/_asarray.py:16(asarray)
#         1    0.000    0.000    0.001    0.001 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/axes/_base.py:982(_gen_axes_spines)
#         1    0.000    0.000    0.001    0.001 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/pyplot.py:2838(plot)
#         5    0.000    0.000    0.001    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/axes/_base.py:997(<genexpr>)
#         4    0.000    0.000    0.001    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/spines.py:484(linear_spine)
#         1    0.000    0.000    0.001    0.001 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/axes/_axes.py:1510(plot)
#         6    0.000    0.000    0.001    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/patches.py:41(__init__)
#        91    0.001    0.000    0.001    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/cbook/__init__.py:2219(_check_isinstance)
#        55    0.000    0.000    0.001    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/artist.py:69(__init__)
#         4    0.000    0.000    0.001    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/spines.py:31(__init__)
#       202    0.000    0.000    0.001    0.000 <__array_function__ internals>:2(shape)
#         1    0.000    0.000    0.001    0.001 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/pyplot.py:555(figure)
#        16    0.000    0.000    0.001    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/transforms.py:1957(rotate_deg_around)
#        12    0.000    0.000    0.001    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/lines.py:1146(set_marker)
#        52    0.000    0.000    0.001    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/markers.py:230(_recache)
#        21    0.000    0.000    0.001    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/font_manager.py:932(copy)
#      5237    0.001    0.000    0.001    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/inspect.py:2539(kind)
#        19    0.000    0.000    0.001    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/lines.py:1190(set_markerfacecolor)
#       292    0.000    0.000    0.001    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/cbook/__init__.py:2045(_setattr_cm)
#        19    0.000    0.000    0.001    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/font_manager.py:713(_from_any)
#       146    0.000    0.000    0.001    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/contextlib.py:108(__enter__)
#         1    0.000    0.000    0.001    0.001 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/pyplot.py:312(new_figure_manager)
#         1    0.000    0.000    0.001    0.001 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/backend_bases.py:3487(new_figure_manager)
#       357    0.000    0.000    0.001    0.000 {built-in method builtins.any}
#        82    0.001    0.000    0.001    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#         1    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/collections.py:232(get_datalim)
#        32    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/axis.py:1610(_set_formatter)
#      1590    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#        20    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/markers.py:215(__init__)
#         1    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/figure.py:250(__init__)
#        16    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/transforms.py:1937(rotate_deg)
#      1495    0.000    0.000    0.000    0.000 {built-in method builtins.getattr}
#        38    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/transforms.py:766(__init__)
#        16    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/transforms.py:1921(rotate)
#        16    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/axis.py:1636(set_major_locator)
#       202    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/numpy/core/fromnumeric.py:1903(shape)
#       146    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/contextlib.py:117(__exit__)
#         1    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/collections.py:939(__init__)
#        18    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/transforms.py:815(from_extents)
#        52    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/transforms.py:1267(__add__)
#       146    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/contextlib.py:238(helper)
#      1608    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#        42    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/colors.py:161(to_rgba)
#       165    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/artist.py:52(_stale_axes_callback)
#        52    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/transforms.py:2433(composite_transform_factory)
#         1    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/axes/_base.py:1956(add_line)
#       103    0.000    0.000    0.000    0.000 {method 'copy' of 'numpy.ndarray' objects}
#        16    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(diff)
#        31    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/transforms.py:1832(__init__)
#        19    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/transforms.py:1019(__init__)
#       115    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/transforms.py:185(set_children)
#       402    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/cbook/__init__.py:2254(_check_in_list)
#         1    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/collections.py:73(__init__)
#      2721    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/inspect.py:2527(name)
#        17    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/patches.py:339(_set_facecolor)
#         2    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/patches.py:722(__init__)
#        13    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/path.py:98(__init__)
#        16    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/numpy/lib/function_base.py:1141(diff)
#         2    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/axes/_base.py:209(__call__)
#        16    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(dot)
#      1247    0.000    0.000    0.000    0.000 {function RcParams.__getitem__ at 0x7fba9e8b5310}
#       146    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/contextlib.py:82(__init__)
#        16    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/axis.py:1570(set_major_formatter)
#        52    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/transforms.py:2276(__init__)
#     28/24    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/spines.py:391(get_spine_transform)
#        11    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(column_stack)
#       100    0.000    0.000    0.000    0.000 <ipython-input-341-dba1344884fb>:238(dotInArea)
#         1    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/axes/_base.py:367(_plot_args)
#       105    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/cbook/__init__.py:1742(<dictcomp>)
#        20    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(atleast_1d)
#         1    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/axes/_subplots.py:95(update_params)
#        17    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/transforms.py:796(unit)
#         1    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/gridspec.py:751(get_position)
#        16    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/axis.py:1596(set_minor_formatter)
#      1405    0.000    0.000    0.000    0.000 {method 'pop' of 'dict' objects}
#        18    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(reshape)
#        11    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/numpy/lib/shape_base.py:612(column_stack)
#        19    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/lines.py:1204(set_markerfacecoloralt)
#        16    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/numpy/ma/core.py:2938(__array_finalize__)
#       204    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/numpy/ma/core.py:1650(make_mask_none)
#       476    0.000    0.000    0.000    0.000 <ipython-input-341-dba1344884fb>:78(crossProduct)
#       121    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/transforms.py:1702(__init__)
#        20    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/numpy/core/shape_base.py:25(atleast_1d)
#        16    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/axis.py:1652(set_minor_locator)
#      1267    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/artist.py:796(get_animated)
#        11    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/patches.py:346(set_facecolor)
#        20    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/numpy/core/fromnumeric.py:55(_wrapfunc)
#        25    0.000    0.000    0.000    0.000 {method 'view' of 'numpy.ndarray' objects}
#       969    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/cbook/deprecation.py:399(<genexpr>)
#       290    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/artist.py:332(pchanged)
#        16    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/ticker.py:518(__init__)
#         1    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/axes/_base.py:418(<listcomp>)
#         1    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/axes/_base.py:308(_makeline)
#        67    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/transforms.py:148(invalidate)
#        18    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/numpy/core/fromnumeric.py:202(reshape)
#        54    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/font_manager.py:887(set_size)
#         1    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/axes/_base.py:1982(_update_line_limits)
#         1    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/axes/_base.py:965(_gen_axes_patch)
#        40    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/font_manager.py:851(set_weight)
#     29/15    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/axes/_base.py:776(get_yaxis_transform)
#        14    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/transforms.py:1982(scale)
#        71    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/artist.py:935(set_visible)
#         1    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/gridspec.py:140(get_grid_positions)
#      1385    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/inspect.py:2531(default)
#        20    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/numpy/core/fromnumeric.py:42(_wrapit)
#         6    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/patches.py:434(set_fill)
#        38    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/font_manager.py:869(set_stretch)
#        16    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/text.py:1039(set_fontsize)
#        54    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/artist.py:687(set_figure)
#        74    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/numpy/core/_asarray.py:88(asanyarray)
#       240    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/transforms.py:107(__init__)
#         3    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/transforms.py:1308(contains_branch)
#       741    0.000    0.000    0.000    0.000 {built-in method builtins.iter}
#        48    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/rcsetup.py:623(validate_capstyle)
#         7    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(broadcast_arrays)
#         1    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/axes/_base.py:621(set_figure)
#        19    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/lines.py:1098(set_linestyle)
#        10    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/cycler.py:349(by_key)
#        27    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/cbook/__init__.py:1281(_to_unmasked_float_array)
#       206    0.000    0.000    0.000    0.000 {built-in method numpy.zeros}
#         1    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/axes/_base.py:3214(set_xlim)
#         3    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/axis.py:518(_get_text1_transform)
#        42    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/colors.py:124(_is_nth_color)
#     29/15    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/axes/_base.py:700(get_xaxis_transform)
#        49    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/artist.py:354(set_transform)
#        21    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/numpy/ma/core.py:2912(_update_from)
#        16    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/scale.py:639(scale_factory)
#         3    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/axes/_base.py:800(get_yaxis_text1_transform)
#       7/4    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/transforms.py:2320(__eq__)
#        19    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/lines.py:1346(set_dash_capstyle)
#         8    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/transforms.py:2252(blended_transform_factory)
#         7    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/numpy/lib/stride_tricks.py:206(broadcast_arrays)
#        32    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/transforms.py:1969(translate)
#     28/24    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/spines.py:215(_ensure_position_is_set)
#         3    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/markers.py:733(_set_tickleft)
#        38    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/font_manager.py:832(set_style)
#         8    0.000    0.000    0.000    0.000 {method 'astype' of 'numpy.ndarray' objects}
#         3    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/transforms.py:1645(__eq__)
#     81/67    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/transforms.py:158(_invalidate_internal)
#        35    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/text.py:1137(set_verticalalignment)
#         6    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/axis.py:1454(update_units)
#         3    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/transforms.py:2091(__eq__)
#         2    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/axes/_base.py:852(_update_transScale)
#         3    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/axis.py:521(_get_text2_transform)
#        90    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/abc.py:96(__instancecheck__)
#         1    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/cbook/__init__.py:961(_combine_masks)
#       7/6    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/transforms.py:1710(__eq__)
#         3    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/axis.py:445(_get_text1_transform)
#         3    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/markers.py:747(_set_tickup)
#      12/6    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/units.py:192(get_converter)
#       323    0.000    0.000    0.000    0.000 {method 'values' of 'mappingproxy' objects}
#         1    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/numpy/ma/core.py:5632(min)
#         6    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/transforms.py:2210(__init__)
#         3    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/axes/_base.py:724(get_xaxis_text1_transform)
#         3    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/axes/_base.py:826(get_yaxis_text2_transform)
#        44    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/rcsetup.py:617(validate_joinstyle)
#         3    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/markers.py:753(_set_tickdown)
#        17    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/patches.py:313(_set_edgecolor)
#        38    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/re.py:188(match)
#        12    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/cbook/__init__.py:168(connect)
#       323    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/inspect.py:2619(__init__)
#       908    0.000    0.000    0.000    0.000 {built-in method math.sqrt}
#        19    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/lines.py:631(set_data)
#         1    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/numpy/ma/extras.py:296(__call__)
#        13    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/transforms.py:2603(__init__)
#        16    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/axis.py:795(reset_ticks)
#         3    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/colors.py:281(to_rgba_array)
#         4    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/axes/_base.py:2161(_process_unit_info)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(vstack)
#        13    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/cbook/__init__.py:2271(_check_shape)
#        30    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/axis.py:332(_set_artist_props)
#         3    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/axis.py:538(update_position)
#        38    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/font_manager.py:842(set_variant)
#       515    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/artist.py:189(axes)
#         1    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/axes/_base.py:3486(set_ylim)
#        18    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/transforms.py:2511(__init__)
#         4    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/spines.py:355(set_position)
#        35    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/text.py:944(set_horizontalalignment)
#         1    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/numpy/core/shape_base.py:224(vstack)
#         8    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/axes/_base.py:2164(_process_single_axis)
#        19    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/lines.py:1302(set_dash_joinstyle)
#       540    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#         2    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/collections.py:754(_set_facecolor)
#        16    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/patches.py:783(_convert_units)
#        57    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/lines.py:67(_scale_dashes)
#        91    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/cbook/__init__.py:2236(type_name)
#        46    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/lines.py:1232(set_xdata)
#         3    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/axis.py:448(_get_text2_transform)
#        19    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/lines.py:716(set_transform)
#         1    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/numpy/ma/core.py:5766(max)
#        40    0.000    0.000    0.000    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#        19    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/text.py:1204(set_usetex)
#         3    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/numpy/ma/core.py:2342(masked_invalid)
#        11    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/patches.py:328(set_edgecolor)
#       223    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/numpy/ma/core.py:1368(getmask)
#        19    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/lines.py:1360(set_solid_capstyle)
#        42    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/artist.py:165(convert_xunits)
#         3    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/axes/_base.py:750(get_xaxis_text2_transform)
#        90    0.000    0.000    0.000    0.000 {built-in method _abc._abc_instancecheck}
#        13    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/path.py:193(_update_values)
#         2    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/cbook/__init__.py:681(safe_masked_invalid)
#         1    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/axes/_base.py:664(_set_lim_and_transforms)
#         3    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/markers.py:739(_set_tickright)
#         1    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/backend_bases.py:3496(new_figure_manager_given_figure)
#        20    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/markers.py:252(set_fillstyle)
#         1    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/axes/_base.py:2123(update_datalim)
#       350    0.000    0.000    0.000    0.000 {method 'lower' of 'str' objects}
#         3    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/numpy/ma/core.py:4511(ravel)
#        38    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/font_manager.py:819(set_family)
#       478    0.000    0.000    0.000    0.000 {method 'append' of 'list' objects}
#         7    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(all)
#        19    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/lines.py:1316(set_solid_joinstyle)
#         2    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/backend_bases.py:1685(__init__)
#        19    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/lines.py:1080(set_linewidth)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(atleast_2d)
#         2    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/transforms.py:1327(contains_branch_seperately)
#         1    0.000    0.000    0.000    0.000 <ipython-input-341-dba1344884fb>:7(findMost)
#         1    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/axes/_base.py:1195(_set_title_offset_trans)
#         1    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/numpy/core/shape_base.py:83(atleast_2d)
#         2    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/transforms.py:1671(set)
#       298    0.000    0.000    0.000    0.000 {built-in method builtins.setattr}
#        20    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/cbook/__init__.py:1268(is_math_text)
#        55    0.000    0.000    0.000    0.000 <string>:1(__new__)
#        46    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/lines.py:1244(set_ydata)
#         1    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/figure.py:1406(_add_axes_internal)
#        71    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/numpy/lib/function_base.py:257(iterable)
#        10    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/patches.py:456(set_capstyle)
#        92    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/rcsetup.py:600(_deprecate_case_insensitive_join_cap)
#       323    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/inspect.py:2845(parameters)
#         1    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/cm.py:219(__init__)
#        19    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/artist.py:1028(set_zorder)
#        21    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/text.py:928(set_color)
#       388    0.000    0.000    0.000    0.000 {built-in method builtins.id}
#         7    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/numpy/lib/stride_tricks.py:185(_broadcast_shape)
#        20    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/text.py:235(set_rotation_mode)
#         7    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/numpy/core/fromnumeric.py:2324(all)
#        16    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/scale.py:98(__init__)
# ...
#         5    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/transforms.py:1691(<lambda>)
#         2    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/cbook/__init__.py:798(__init__)
#         1    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/projections/__init__.py:44(get_projection_class)
#         1    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/cbook/__init__.py:1841(_str_lower_equal)
#         1    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/_pylab_helpers.py:34(get_fig_manager)
#         5    0.000    0.000    0.000    0.000 {built-in method _abc._abc_subclasscheck}
#         7    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/cbook/__init__.py:1610(<lambda>)
#         1    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/transforms.py:2055(transform)
#        16    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/transforms.py:1294(depth)
#         2    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/axis.py:1359(get_major_locator)
#         1    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/cbook/__init__.py:552(__init__)
#         1    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/figure.py:91(_entry_from_axes)
#         3    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/cbook/__init__.py:605(clear)
#         4    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/cbook/__init__.py:91(__init__)
#         7    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/path.py:202(vertices)
#         2    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/numpy/ma/core.py:789(is_string_or_list_of_strings)
#         3    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/transforms.py:2334(<lambda>)
#         2    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/figure.py:194(update)
#         2    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/axes/_base.py:656(_request_autoscale_view)
#         1    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/axes/_base.py:3101(set_axis_on)
#         3    0.000    0.000    0.000    0.000 {method 'copy' of 'list' objects}
#         7    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/numpy/lib/stride_tricks.py:202(_broadcast_arrays_dispatcher)
#         1    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/cbook/__init__.py:2112(__init__)
#         1    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/collections.py:470(set_urls)
#         1    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/__init__.py:1207(is_interactive)
#         2    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/numpy/ma/core.py:3191(_is_scalar)
#         4    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/transforms.py:971(get_points)
#         1    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/transforms.py:963(minposx)
#         2    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/axes/_base.py:638(<genexpr>)
#         1    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/transforms.py:363(height)
#         1    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/backend_bases.py:2708(notify_axes_change)
#         1    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/collections.py:493(set_hatch)
#         2    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/axes/_base.py:289(<genexpr>)
#         1    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/collections.py:225(get_offset_transform)
#         1    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/transforms.py:241(__array__)
#         6    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/axis.py:145(<dictcomp>)
#         7    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/numpy/core/fromnumeric.py:2320(_all_dispatcher)
#         5    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/artist.py:1213(mouseover)
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.abs}
#         1    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/text.py:1124(set_rotation)
#         1    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/collections.py:958(set_paths)
#         4    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/axis.py:1433(<dictcomp>)
#         1    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/axes/_base.py:299(_setdefaults)
#         5    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/artist.py:346(is_transform_set)
#         1    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/path.py:764(unit_circle)
#         1    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/numpy/ma/core.py:3462(mask)
#         2    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/widgets.py:35(__init__)
#         1    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/projections/__init__.py:19(get_projection_class)
#         2    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/axis.py:750(get_scale)
#         3    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/gridspec.py:74(get_geometry)
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.issubclass}
#         1    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/copyreg.py:90(__newobj__)
#         4    0.000    0.000    0.000    0.000 {method 'values' of 'collections.OrderedDict' objects}
#         1    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/markers.py:411(_half_fill)
#         1    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/gridspec.py:211(_normalize)
#         1    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/weakref.py:73(__eq__)
#         2    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/colors.py:114(_sanitize_extrema)
#         2    0.000    0.000    0.000    0.000 {method 'index' of 'list' objects}
#         2    0.000    0.000    0.000    0.000 {method 'sort' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/axes/_base.py:3752(set_navigate)
#         3    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/path.py:216(codes)
#         1    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/transforms.py:967(minposy)
#         2    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/transforms.py:1865(get_matrix)
#         2    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/artist.py:819(get_clip_path)
#         3    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/artist.py:1004(get_label)
#         1    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/gridspec.py:120(set_height_ratios)
#         3    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/axes/_base.py:378(<genexpr>)
#         1    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/figure.py:1059(fixitems)
#         2    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/figure.py:69(<listcomp>)
#         1    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/figure.py:92(<dictcomp>)
#         2    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/axes/_base.py:640(<genexpr>)
#         1    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/axes/_base.py:2586(_get_axis_list)
#         1    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/artist.py:959(set_in_layout)
#         2    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/numpy/core/multiarray.py:1043(copyto)
#         1    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/collections.py:418(set_pickradius)
#         1    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/gridspec.py:703(num2)
#         2    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/axis.py:569(locator)
#         2    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/numpy/core/fromnumeric.py:2401(_cumsum_dispatcher)
#         2    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/figure.py:480(get_constrained_layout)
#         1    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/cbook/__init__.py:94(__call__)
#         1    0.000    0.000    0.000    0.000 {method 'copy' of 'dict' objects}
#         2    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/artist.py:792(get_visible)
#         2    0.000    0.000    0.000    0.000 {built-in method sys.is_finalizing}
#         2    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/path.py:247(should_simplify)
#         1    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/axes/_base.py:3768(set_navigate_mode)
#         2    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/figure.py:71(<listcomp>)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         2    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/cbook/__init__.py:799(<dictcomp>)
#         1    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/collections.py:962(get_paths)
#         2    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/scale.py:80(limit_range_for_scale)
#         1    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/gridspec.py:100(set_width_ratios)
#         2    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/markers.py:249(get_fillstyle)
#         1    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/axes/_subplots.py:83(get_subplotspec)
#         1    0.000    0.000    0.000    0.000 {method 'items' of 'collections.OrderedDict' objects}
#         1    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/numpy/core/multiarray.py:990(unravel_index)
#         2    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/path.py:235(simplify_threshold)
#         1    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/markers.py:315(get_path)
#         1    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/markers.py:246(is_filled)
#         1    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/gridspec.py:710(get_gridspec)
#         1    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/gridspec.py:699(num2)
#         1    0.000    0.000    0.000    0.000 {method 'move_to_end' of 'collections.OrderedDict' objects}
#         1    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/numpy/core/shape_base.py:79(_atleast_2d_dispatcher)

# %% [markdown]
# *Optional*: Feel free to use the code below on small datasets (e.g., N = 10) to visually inspect whether the algorithm has been implemented correctly. The fragment below assumes both `inputSet` and `outputSet` to be lists of 2D points, with each point being a list of 2 elements (e.g., `[[x1,y1], [x2,y2], ..., [x_k,y_k]]`)

# %%
import matplotlib.pyplot as plt

# inputSet and outputSet should have been defined above. 
# uncomment the next two lines only if you wish to test the plotting code before coding your algorithm

#inputSet = [[1,1], [2,2] , [3, 3], [4,4], [1,4], [3,1], [1, 5], [2, 4], [3, 5]]
#outputSet = [[1,1], [3,1] , [4, 4], [3,5], [1,5]]

plt.figure()

#first do a scatter plot of the inputSet
input_xs, input_ys = zip(*inputSet)
plt.scatter(input_xs, input_ys)

#then do a polygon plot of the computed covex hull
outputSet.append(outputSet[0]) #first create a 'closed loop' by adding the first point at the end of the list
output_xs, output_ys = zip(*outputSet) 
plt.plot(output_xs, output_ys) 

plt.show()
